# %% [markdown]
# <a href="https://colab.research.google.com/github/pranav19611/EDS/blob/main/26_06_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,10])
y=np.array([0,100])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,10])
y=np.array([0,100])
plt.plot(x,y)
plt.show()

# %%
x=np.linspace(0,10,100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='blue',linestyle='-')
plt.plot(x,np.sin(x-1),color='g',linestyle='--')
plt.plot(x,np.sin(x-2),color='0.75',linestyle='-.')
plt.plot(x,np.sin(x-3),color='#FFdd44',linestyle=':')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,2,3,4,5]
y=[10,15,7,12,9]

plt.plot(x,y,marker='*')
plt.title('Line chart example')
plt.xlabel('time')
plt.ylabel('dependent')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
categories=['Day1','day2','day3','day4']
values=[25,40,15,50]
plt.bar(categories,values)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
categories=['Day1','day2','day3','day4']
values=[25,40,15,50]
plt.barh(categories,values)
plt.show()

# %%
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
x=np.array([3,4,5,7,2,5,9,8,5,4,12,11,10])
y=np.array([89,98,76,69,78,90,66,96,90,111,101,98,96])
plt.scatter(x,y)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=['sic','eds','am','son']
plt.pie(y,labels=mylabels)
plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 20}
names = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize=(4,3))
ax = plt.axes()

ax.bar(names, values, color='teal', width = 0.35);
ax.set_xlabel('Fruit')
ax.set_ylabel('Quantity')
ax.set_title('Fruit Quantities');
