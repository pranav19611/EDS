# %% [markdown]
# <a href="https://colab.research.google.com/github/pranav19611/EDS/blob/main/28_06_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/data.csv")
print(df)
df.plot()
plt.show()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df1=pd.read_csv("/content/coffee - coffee.csv")
df1.plot()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv("/content/coffee - coffee.csv")
df1.plot(x='Bag Weight', y='Aroma')
plt.show()

# %%
y=df1['Country of Origin'].tolist()
l=df1['Bag Weight'].tolist()
print(y)
print(l)
#plt.pie(y,labels=l)
plt.show()
# Out:
# ['Colombia', 'Taiwan', 'Laos', 'Costa Rica', 'Colombia', 'Guatemala', 'Taiwan', 'Taiwan', 'Taiwan', 'Tanzania, United Republic Of', 'Ethiopia', 'Guatemala', 'Taiwan', 'Ethiopia', 'Colombia', 'Taiwan', 'Ethiopia', 'Taiwan', 'Taiwan', 'Tanzania, United Republic Of', 'Guatemala', 'Taiwan', 'Thailand', 'Colombia', 'Taiwan', 'Brazil', 'Taiwan', 'Taiwan', 'Taiwan', 'United States (Hawaii)', 'Taiwan', 'Taiwan', 'Taiwan', 'Ethiopia']
# ['35 kg', '80 kg', '25 kg', '22 kg', '24 kg', '30 kg', '27 kg', '90 kg', '30 kg', '60 kg', '30 kg', '15 kg', '60 kg', '60 kg', '35 kg', '60 kg', '5 kg', '2 kg', '1 kg', '30 kg', '30 kg', '20 kg', '1 kg', '5 kg', '50 kg', '60 kg', '100 kg', '90 kg', '85 kg', '15 kg', '48 kg', '50 kg', '5 kg', '60 kg']
